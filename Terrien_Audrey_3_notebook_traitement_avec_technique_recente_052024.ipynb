# %% [markdown]
# # Classifiez automatiquement des biens de consommation - partie textuelle - modélisation non supervisée

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# __Contexte__
#
# Place de marché® est un e-commerce qui met direction en relation les vendeurs et les acheteurs. A ce jour, les vendeurs doivent insérer une photo, une description du produit qu'ils vendent et aussi le trier dans sa catégorie. Cependant, il arrive que ces derniers se trompent dans lorsqu'ils le catégorisent.
#
# __Problématiques__
#
# C'est pourquoi Place de marché souhaite automatiser la catégorisation des produits à partir de son image et/ou de sa description avec l'aide d'un moteur de classifiation automatique.
#
# __Droits d'utilisation des données Flipkart__
#
# Le dossier Flipkart a été échantillonné à partir des données mises sur Kaggle, avec l'autorisation de Flipkart: comme il est visible dans cette image ci-dessous où nous voyons qu'ils sont sous la licence [CC BY-SA 4.0](https://creativecommons.org/licenses/by-sa/4.0/) qui stipule qu'il est possible d'utiliser, de modifier et de partager ces données. Nous pouvons donc continuer le reste de l'étude de faisabilité sans nous soucier d'enfreindre la loi de ce côté-là.
#
# Cependant cela n'inclut que le dataframe. Malheureusement, j'ai beau cherché, rien n'indique que les images peuvent être utilisées: voire même Flipkart stipule dans sa page "https://affiliate.flipkart.com/terms-of-use" dans la section "Trademark, Copyright and Restriction" que nous ne pouvons pas l'utiliser sans leur autorisation. Cependant, comme ce dataset est utilisé par OpenClassrooms, j'en ai conclu qu'il était possible que je travaille sur ce dernier.

# %% [markdown]
# ![proof_of_use.png](data:image/png;base64,...)

# %% [markdown]
# ### Les critères à remplir dans ce notebook
#    1. __Prétraiter des données images pour obtenir un jeu de données exploitable.__
#       - CE1 Vous avez utilisé des librairies spécialisées pour un premier traitement du contraste (ex. : openCV).
#       - CE3 Vous avez élaboré une fonction permettant d'extraire des features ("feature engineering") de type "bag-of-images" via la génération de descripteurs (algorithmes ORB, ou SIFT, ou SURF).
#       - CE4 Vous avez élaboré et exécuté une fonction permettant d'extraire des features ("feature engineering") via un algorithme de Transfer Learning basé sur des réseaux de neurones, comme par exemple CNN.
#
#    2. __Mettre en œuvre des techniques de réduction de dimension.__
#       - CE1 Vous avez justifié la nécessité de la réduction de dimension.
#       - CE2 Vous avez appliqué une méthode de réduction de dimension adaptée à la problématique (ex. : ACP).
#       - CE3 Vous avez justifié le choix des valeurs des paramètres dans la méthode de réduction de dimension retenue (ex. : le nombre de dimensions conservées pour l'ACP).
#
#    3. __Représenter graphiquement des données à grandes dimensions.__
#       - CE1 Vous avez mis en œuvre au moins une technique de réduction de dimension (via LDA, ACP, T-SNE, UMAP ou autre technique).
#       - CE2 Vous avez réalisé au moins un graphique représentant les données réduites en 2D (par exemple affichage des 2 composantes du T-SNE).
#       - CE3 Vous avez réalisé et formalisé une analyse du graphique en 2D.

# %% [markdown]
# ## Préparation de l'environnement
#
# __Importation des librairies et du jeu de données__

# %%
# Importation des librairies de base
import gc
import pandas as pd
import numpy as np
import time
import warnings
from matplotlib.colors import ListedColormap, BoundaryNorm
from sklearn.preprocessing import LabelEncoder

# Importation des fonctions personnelles
#from .my_packages import *
import sys
sys.path.append('my_packages')

from my_packages import *
#from my_packages import *

# Cache les warnings
warnings.filterwarnings('ignore')

# %%
# Importation de tensorflow pour traiter les images
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

# %%
# Importation des librairies keras pour MobileNetV2
from tensorflow.keras import backend
from tensorflow.python.client import device_lib

# Toujours nettoyer le backend avant d'entraîner un modèle
# https://keras.io/api/utils/backend_utils/
backend.clear_session()

# Vérification de la présence ou non d'un GPU 
print(device_lib.list_local_devices())

# Check available devices (GPU or CPU)
devices = tf.config.experimental.list_physical_devices('GPU')

if len(devices) == 0: print("No GPU devices found.") 
else: print("GPU devices found:", devices)

del devices
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7218209334195961148
# xla_global_id: -1
# ]
# No GPU devices found.

# %%
# Réimportation uniquement des données textuelles nécessaires
df = pd.read_csv(PATH_input+'flipkart_com-ecommerce_sample_1050.csv')   
df['CATEGORY'] = df['product_category_tree'].map(lambda x: x.split("[\"")[1].split(" >>", 1)[0])
df = df[['CATEGORY', 'image']]
df['image'] = PATH_resized_images + df['image']
df.columns = ['CATEGORY', 'IMAGE']
df.sample()
# Out:
#       CATEGORY                                              IMAGE
# 629  Baby Care  /Users/audreyterrien/Documents/github_reposito...

# %%
# Liste des catégories
le = LabelEncoder()
cat_list = list(np.unique(df.CATEGORY))
print("catégories : ", cat_list)

# Création du label qui sera utilisé lors de la comparaison ARI
true_label = le.fit_transform(df['CATEGORY'])

# Nombre de clusters
n_clusters = len(cat_list)

# Définir l'ordre des catégories et leurs couleurs respectives
palette = {'Baby Care': 'violet', 
           'Beauty and Personal Care': 'blue', 
           'Computers': 'gray', 
           'Home Decor & Festive Needs': 'green',
           'Home Furnishing': 'orange', 
           'Kitchen & Dining': 'red', 
           'Watches': 'brown'}
           
my_colors = ['violet', 'blue',  'gray', 'green', 'orange', 'red','brown']
my_cmap = ListedColormap(my_colors)

# Fixer les couleurs pour chaque catégorie
boundaries = np.arange(len(cat_list) + 1)
norm = BoundaryNorm(boundaries, my_cmap.N)
# Out:
# catégories :  ['Baby Care', 'Beauty and Personal Care', 'Computers', 'Home Decor & Festive Needs', 'Home Furnishing', 'Kitchen & Dining', 'Watches']

# %% [markdown]
# ### VGG16

# %%
# %%time
from tensorflow.keras.applications.vgg16 import preprocess_input, VGG16

# Chargement du modèle VGG16 pré-entraîné
start_time = time.time()
base_model = VGG16(weights='imagenet')
model = Model(inputs=base_model.inputs, outputs=base_model.layers[-2].output)
model._name = model_name = 'VGG16'
print(model.summary())
print(f'Temps de la récupération du modèle en {round(time.time() - start_time,2)}s')

# Prédiction des features pour chaque image
start_time = time.time()
features = []
i=0 
for image_file in df["IMAGE"] :
    if i%100 == 0 : print(i)
    i +=1
    image = load_img(image_file, target_size=(224, 224))
    image = img_to_array(image) 
    image = np.expand_dims(image, axis=0)
    image = preprocess_input(image)
    features.append(model.predict(image, verbose=0)[0]) # predict from pretrained model

features = np.asarray(features)
print('Shape of features:', features.shape)
print(f'Temps de la prédiction des featuresen {round(time.time() - start_time,2)}s')

# Réduction ou pas du nombre de features 
start_time = time.time()
X_embedded, pred_label, pipeline = perform_dimensionality_reduction_Kfold(features, use_pca=True,\
    perplexity=30, n_iter=2000, n_clusters=n_clusters, random_state=None, n_splits=5)
print(f'Temps de réduction des dimensions des features en {round(time.time() - start_time,2)}s')

_,_,_ = evaluate_model(model_name, X_embedded, pred_label, true_label, le=le,\
    my_cmap=my_cmap, norm=norm, cat_list=cat_list, palette=palette)
# Out:
# Model: "VGG16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
# =================================================================
# Total params: 134260544 (512.16 MB)
# Trainable params: 134260544 (512.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# CPU times: user 13min 44s, sys: 1min 7s, total: 14min 52s
# Wall time: 2min 33s
# (1050, 4096)

# %%
gc.collect()

# %% [markdown]
# ### Inception v3
# https://keras.io/api/applications/#usage-examples-for-image-classification-models

# %%
# %%time
# Chargement du modèle VGG16 pré-entraîné
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input

start_time = time.time()
input_tensor = Input(shape=(224, 224, 3))
base_model = InceptionV3(weights='imagenet', input_tensor=input_tensor)
model = Model(inputs=base_model.inputs, outputs=base_model.layers[-2].output)
model._name = model_name = 'InceptionV3'
print(model.summary())
print(f'Temps de la récupération du modèle en {round(time.time() - start_time,2)}s')

# Prédiction des features pour chaque image
start_time = time.time()
features = []
i=0 
for image_file in df["IMAGE"] :
    if i%100 == 0 : print(i)
    i +=1
    image = load_img(image_file, target_size=(224, 224))
    image = img_to_array(image) 
    image = np.expand_dims(image, axis=0)
    image = preprocess_input(image)
    features.append(model.predict(image, verbose=0)[0]) # predict from pretrained model

features = np.asarray(features)
print('Shape of features:', features.shape)
print(f'Temps de la prédiction des featuresen {round(time.time() - start_time,2)}s')

# Réduction ou pas du nombre de features 
start_time = time.time()
X_embedded, pred_label, pipeline = perform_dimensionality_reduction(features, use_pca=False, \
    perplexity=25, n_iter=2000, n_clusters=n_clusters, random_state=None)
print(f'Temps de réduction des dimensions des features en {round(time.time() - start_time,2)}s')

# Evaluations graphiques et sous forme de table du modèle non-supervisé
_,_,_ = evaluate_model(model_name, X_embedded, pred_label, true_label, le=le, my_cmap=my_cmap, \
    norm=norm, cat_list=cat_list, palette=palette)
# Out:
# Model: "InceptionV3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_14 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv2d_564 (Conv2D)         (None, 111, 111, 32)         864       ['input_14[0][0]']
#
#  batch_normalization_564 (B  (None, 111, 111, 32)         96        ['conv2d_564[0][0]']
#  atchNormalization)
#
#  activation_564 (Activation  (None, 111, 111, 32)         0         ['batch_normalization_564[0][0
#  )                                                                  ]']
#
#  conv2d_565 (Conv2D)         (None, 109, 109, 32)         9216      ['activation_564[0][0]']
#
#  batch_normalization_565 (B  (None, 109, 109, 32)         96        ['conv2d_565[0][0]']
#  atchNormalization)
#
#  activation_565 (Activation  (None, 109, 109, 32)         0         ['batch_normalization_565[0][0
#  )                                                                  ]']
#
#  conv2d_566 (Conv2D)         (None, 109, 109, 64)         18432     ['activation_565[0][0]']
#
#  batch_normalization_566 (B  (None, 109, 109, 64)         192       ['conv2d_566[0][0]']
#  atchNormalization)
#
#  activation_566 (Activation  (None, 109, 109, 64)         0         ['batch_normalization_566[0][0
#  )                                                                  ]']
#
#  max_pooling2d_24 (MaxPooli  (None, 54, 54, 64)           0         ['activation_566[0][0]']
#  ng2D)
#
#  conv2d_567 (Conv2D)         (None, 54, 54, 80)           5120      ['max_pooling2d_24[0][0]']
#
#  batch_normalization_567 (B  (None, 54, 54, 80)           240       ['conv2d_567[0][0]']
#  atchNormalization)
#
#  activation_567 (Activation  (None, 54, 54, 80)           0         ['batch_normalization_567[0][0
#  )                                                                  ]']
#
#  conv2d_568 (Conv2D)         (None, 52, 52, 192)          138240    ['activation_567[0][0]']
#
#  batch_normalization_568 (B  (None, 52, 52, 192)          576       ['conv2d_568[0][0]']
#  atchNormalization)
#
#  activation_568 (Activation  (None, 52, 52, 192)          0         ['batch_normalization_568[0][0
#  )                                                                  ]']
#
#  max_pooling2d_25 (MaxPooli  (None, 25, 25, 192)          0         ['activation_568[0][0]']
#  ng2D)
#
#  conv2d_572 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_25[0][0]']
#
#  batch_normalization_572 (B  (None, 25, 25, 64)           192       ['conv2d_572[0][0]']
#  atchNormalization)
#
#  activation_572 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_572[0][0
#  )                                                                  ]']
#
#  conv2d_570 (Conv2D)         (None, 25, 25, 48)           9216      ['max_pooling2d_25[0][0]']
#
#  conv2d_573 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_572[0][0]']
#
#  batch_normalization_570 (B  (None, 25, 25, 48)           144       ['conv2d_570[0][0]']
#  atchNormalization)
#
#  batch_normalization_573 (B  (None, 25, 25, 96)           288       ['conv2d_573[0][0]']
#  atchNormalization)
#
#  activation_570 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_570[0][0
#  )                                                                  ]']
#
#  activation_573 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_573[0][0
#  )                                                                  ]']
#
#  average_pooling2d_54 (Aver  (None, 25, 25, 192)          0         ['max_pooling2d_25[0][0]']
#  agePooling2D)
#
#  conv2d_569 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_25[0][0]']
#
#  conv2d_571 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_570[0][0]']
#
#  conv2d_574 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_573[0][0]']
#
#  conv2d_575 (Conv2D)         (None, 25, 25, 32)           6144      ['average_pooling2d_54[0][0]']
#
#  batch_normalization_569 (B  (None, 25, 25, 64)           192       ['conv2d_569[0][0]']
#  atchNormalization)
#
#  batch_normalization_571 (B  (None, 25, 25, 64)           192       ['conv2d_571[0][0]']
#  atchNormalization)
#
#  batch_normalization_574 (B  (None, 25, 25, 96)           288       ['conv2d_574[0][0]']
#  atchNormalization)
#
#  batch_normalization_575 (B  (None, 25, 25, 32)           96        ['conv2d_575[0][0]']
#  atchNormalization)
#
#  activation_569 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_569[0][0
#  )                                                                  ]']
#
#  activation_571 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_571[0][0
#  )                                                                  ]']
#
#  activation_574 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_574[0][0
#  )                                                                  ]']
#
#  activation_575 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_575[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 25, 25, 256)          0         ['activation_569[0][0]',
#                                                                      'activation_571[0][0]',
#                                                                      'activation_574[0][0]',
#                                                                      'activation_575[0][0]']
#
#  conv2d_579 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_579 (B  (None, 25, 25, 64)           192       ['conv2d_579[0][0]']
#  atchNormalization)
#
#  activation_579 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_579[0][0
#  )                                                                  ]']
#
#  conv2d_577 (Conv2D)         (None, 25, 25, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_580 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_579[0][0]']
#
#  batch_normalization_577 (B  (None, 25, 25, 48)           144       ['conv2d_577[0][0]']
#  atchNormalization)
#
#  batch_normalization_580 (B  (None, 25, 25, 96)           288       ['conv2d_580[0][0]']
#  atchNormalization)
#
#  activation_577 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_577[0][0
#  )                                                                  ]']
#
#  activation_580 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_580[0][0
#  )                                                                  ]']
#
#  average_pooling2d_55 (Aver  (None, 25, 25, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_576 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_578 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_577[0][0]']
#
#  conv2d_581 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_580[0][0]']
#
#  conv2d_582 (Conv2D)         (None, 25, 25, 64)           16384     ['average_pooling2d_55[0][0]']
#
#  batch_normalization_576 (B  (None, 25, 25, 64)           192       ['conv2d_576[0][0]']
#  atchNormalization)
#
#  batch_normalization_578 (B  (None, 25, 25, 64)           192       ['conv2d_578[0][0]']
#  atchNormalization)
#
#  batch_normalization_581 (B  (None, 25, 25, 96)           288       ['conv2d_581[0][0]']
#  atchNormalization)
#
#  batch_normalization_582 (B  (None, 25, 25, 64)           192       ['conv2d_582[0][0]']
#  atchNormalization)
#
#  activation_576 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_576[0][0
#  )                                                                  ]']
#
#  activation_578 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_578[0][0
#  )                                                                  ]']
#
#  activation_581 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_581[0][0
#  )                                                                  ]']
#
#  activation_582 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_582[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 25, 25, 288)          0         ['activation_576[0][0]',
#                                                                      'activation_578[0][0]',
#                                                                      'activation_581[0][0]',
#                                                                      'activation_582[0][0]']
#
#  conv2d_586 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_586 (B  (None, 25, 25, 64)           192       ['conv2d_586[0][0]']
#  atchNormalization)
#
#  activation_586 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_586[0][0
#  )                                                                  ]']
#
#  conv2d_584 (Conv2D)         (None, 25, 25, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_587 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_586[0][0]']
#
#  batch_normalization_584 (B  (None, 25, 25, 48)           144       ['conv2d_584[0][0]']
#  atchNormalization)
#
#  batch_normalization_587 (B  (None, 25, 25, 96)           288       ['conv2d_587[0][0]']
#  atchNormalization)
#
#  activation_584 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_584[0][0
#  )                                                                  ]']
#
#  activation_587 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_587[0][0
#  )                                                                  ]']
#
#  average_pooling2d_56 (Aver  (None, 25, 25, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_583 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_585 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_584[0][0]']
#
#  conv2d_588 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_587[0][0]']
#
#  conv2d_589 (Conv2D)         (None, 25, 25, 64)           18432     ['average_pooling2d_56[0][0]']
#
#  batch_normalization_583 (B  (None, 25, 25, 64)           192       ['conv2d_583[0][0]']
#  atchNormalization)
#
#  batch_normalization_585 (B  (None, 25, 25, 64)           192       ['conv2d_585[0][0]']
#  atchNormalization)
#
#  batch_normalization_588 (B  (None, 25, 25, 96)           288       ['conv2d_588[0][0]']
#  atchNormalization)
#
#  batch_normalization_589 (B  (None, 25, 25, 64)           192       ['conv2d_589[0][0]']
#  atchNormalization)
#
#  activation_583 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_583[0][0
#  )                                                                  ]']
#
#  activation_585 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_585[0][0
#  )                                                                  ]']
#
#  activation_588 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_588[0][0
#  )                                                                  ]']
#
#  activation_589 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_589[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 25, 25, 288)          0         ['activation_583[0][0]',
#                                                                      'activation_585[0][0]',
#                                                                      'activation_588[0][0]',
#                                                                      'activation_589[0][0]']
#
#  conv2d_591 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_591 (B  (None, 25, 25, 64)           192       ['conv2d_591[0][0]']
#  atchNormalization)
#
#  activation_591 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_591[0][0
#  )                                                                  ]']
#
#  conv2d_592 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_591[0][0]']
#
#  batch_normalization_592 (B  (None, 25, 25, 96)           288       ['conv2d_592[0][0]']
#  atchNormalization)
#
#  activation_592 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_592[0][0
#  )                                                                  ]']
#
#  conv2d_590 (Conv2D)         (None, 12, 12, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_593 (Conv2D)         (None, 12, 12, 96)           82944     ['activation_592[0][0]']
#
#  batch_normalization_590 (B  (None, 12, 12, 384)          1152      ['conv2d_590[0][0]']
#  atchNormalization)
#
#  batch_normalization_593 (B  (None, 12, 12, 96)           288       ['conv2d_593[0][0]']
#  atchNormalization)
#
#  activation_590 (Activation  (None, 12, 12, 384)          0         ['batch_normalization_590[0][0
#  )                                                                  ]']
#
#  activation_593 (Activation  (None, 12, 12, 96)           0         ['batch_normalization_593[0][0
#  )                                                                  ]']
#
#  max_pooling2d_26 (MaxPooli  (None, 12, 12, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 12, 12, 768)          0         ['activation_590[0][0]',
#                                                                      'activation_593[0][0]',
#                                                                      'max_pooling2d_26[0][0]']
#
#  conv2d_598 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_598 (B  (None, 12, 12, 128)          384       ['conv2d_598[0][0]']
#  atchNormalization)
#
#  activation_598 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_598[0][0
#  )                                                                  ]']
#
#  conv2d_599 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_598[0][0]']
#
#  batch_normalization_599 (B  (None, 12, 12, 128)          384       ['conv2d_599[0][0]']
#  atchNormalization)
#
#  activation_599 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_599[0][0
#  )                                                                  ]']
#
#  conv2d_595 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_600 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_599[0][0]']
#
#  batch_normalization_595 (B  (None, 12, 12, 128)          384       ['conv2d_595[0][0]']
#  atchNormalization)
#
#  batch_normalization_600 (B  (None, 12, 12, 128)          384       ['conv2d_600[0][0]']
#  atchNormalization)
#
#  activation_595 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_595[0][0
#  )                                                                  ]']
#
#  activation_600 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_600[0][0
#  )                                                                  ]']
#
#  conv2d_596 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_595[0][0]']
#
#  conv2d_601 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_600[0][0]']
#
#  batch_normalization_596 (B  (None, 12, 12, 128)          384       ['conv2d_596[0][0]']
#  atchNormalization)
#
#  batch_normalization_601 (B  (None, 12, 12, 128)          384       ['conv2d_601[0][0]']
#  atchNormalization)
#
#  activation_596 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_596[0][0
#  )                                                                  ]']
#
#  activation_601 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_601[0][0
#  )                                                                  ]']
#
#  average_pooling2d_57 (Aver  (None, 12, 12, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_594 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_597 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_596[0][0]']
#
#  conv2d_602 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_601[0][0]']
#
#  conv2d_603 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_57[0][0]']
#
#  batch_normalization_594 (B  (None, 12, 12, 192)          576       ['conv2d_594[0][0]']
#  atchNormalization)
#
#  batch_normalization_597 (B  (None, 12, 12, 192)          576       ['conv2d_597[0][0]']
#  atchNormalization)
#
#  batch_normalization_602 (B  (None, 12, 12, 192)          576       ['conv2d_602[0][0]']
#  atchNormalization)
#
#  batch_normalization_603 (B  (None, 12, 12, 192)          576       ['conv2d_603[0][0]']
#  atchNormalization)
#
#  activation_594 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_594[0][0
#  )                                                                  ]']
#
#  activation_597 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_597[0][0
#  )                                                                  ]']
#
#  activation_602 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_602[0][0
#  )                                                                  ]']
#
#  activation_603 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_603[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 12, 12, 768)          0         ['activation_594[0][0]',
#                                                                      'activation_597[0][0]',
#                                                                      'activation_602[0][0]',
#                                                                      'activation_603[0][0]']
#
#  conv2d_608 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_608 (B  (None, 12, 12, 160)          480       ['conv2d_608[0][0]']
#  atchNormalization)
#
#  activation_608 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_608[0][0
#  )                                                                  ]']
#
#  conv2d_609 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_608[0][0]']
#
#  batch_normalization_609 (B  (None, 12, 12, 160)          480       ['conv2d_609[0][0]']
#  atchNormalization)
#
#  activation_609 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_609[0][0
#  )                                                                  ]']
#
#  conv2d_605 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_610 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_609[0][0]']
#
#  batch_normalization_605 (B  (None, 12, 12, 160)          480       ['conv2d_605[0][0]']
#  atchNormalization)
#
#  batch_normalization_610 (B  (None, 12, 12, 160)          480       ['conv2d_610[0][0]']
#  atchNormalization)
#
#  activation_605 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_605[0][0
#  )                                                                  ]']
#
#  activation_610 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_610[0][0
#  )                                                                  ]']
#
#  conv2d_606 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_605[0][0]']
#
#  conv2d_611 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_610[0][0]']
#
#  batch_normalization_606 (B  (None, 12, 12, 160)          480       ['conv2d_606[0][0]']
#  atchNormalization)
#
#  batch_normalization_611 (B  (None, 12, 12, 160)          480       ['conv2d_611[0][0]']
#  atchNormalization)
#
#  activation_606 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_606[0][0
#  )                                                                  ]']
#
#  activation_611 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_611[0][0
#  )                                                                  ]']
#
#  average_pooling2d_58 (Aver  (None, 12, 12, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_604 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_607 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_606[0][0]']
#
#  conv2d_612 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_611[0][0]']
#
#  conv2d_613 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_58[0][0]']
#
#  batch_normalization_604 (B  (None, 12, 12, 192)          576       ['conv2d_604[0][0]']
#  atchNormalization)
#
#  batch_normalization_607 (B  (None, 12, 12, 192)          576       ['conv2d_607[0][0]']
#  atchNormalization)
#
#  batch_normalization_612 (B  (None, 12, 12, 192)          576       ['conv2d_612[0][0]']
#  atchNormalization)
#
#  batch_normalization_613 (B  (None, 12, 12, 192)          576       ['conv2d_613[0][0]']
#  atchNormalization)
#
#  activation_604 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_604[0][0
#  )                                                                  ]']
#
#  activation_607 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_607[0][0
#  )                                                                  ]']
#
#  activation_612 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_612[0][0
#  )                                                                  ]']
#
#  activation_613 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_613[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 12, 12, 768)          0         ['activation_604[0][0]',
#                                                                      'activation_607[0][0]',
#                                                                      'activation_612[0][0]',
#                                                                      'activation_613[0][0]']
#
#  conv2d_618 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_618 (B  (None, 12, 12, 160)          480       ['conv2d_618[0][0]']
#  atchNormalization)
#
#  activation_618 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_618[0][0
#  )                                                                  ]']
#
#  conv2d_619 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_618[0][0]']
#
#  batch_normalization_619 (B  (None, 12, 12, 160)          480       ['conv2d_619[0][0]']
#  atchNormalization)
#
#  activation_619 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_619[0][0
#  )                                                                  ]']
#
#  conv2d_615 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_620 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_619[0][0]']
#
#  batch_normalization_615 (B  (None, 12, 12, 160)          480       ['conv2d_615[0][0]']
#  atchNormalization)
#
#  batch_normalization_620 (B  (None, 12, 12, 160)          480       ['conv2d_620[0][0]']
#  atchNormalization)
#
# ...
#  activation_641 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_641[0][0
#  )                                                                  ]']
#
#  activation_645 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_645[0][0
#  )                                                                  ]']
#
#  conv2d_642 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_641[0][0]']
#
#  conv2d_643 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_641[0][0]']
#
#  conv2d_646 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_645[0][0]']
#
#  conv2d_647 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_645[0][0]']
#
#  average_pooling2d_61 (Aver  (None, 5, 5, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_640 (Conv2D)         (None, 5, 5, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_642 (B  (None, 5, 5, 384)            1152      ['conv2d_642[0][0]']
#  atchNormalization)
#
#  batch_normalization_643 (B  (None, 5, 5, 384)            1152      ['conv2d_643[0][0]']
#  atchNormalization)
#
#  batch_normalization_646 (B  (None, 5, 5, 384)            1152      ['conv2d_646[0][0]']
#  atchNormalization)
#
#  batch_normalization_647 (B  (None, 5, 5, 384)            1152      ['conv2d_647[0][0]']
#  atchNormalization)
#
#  conv2d_648 (Conv2D)         (None, 5, 5, 192)            245760    ['average_pooling2d_61[0][0]']
#
#  batch_normalization_640 (B  (None, 5, 5, 320)            960       ['conv2d_640[0][0]']
#  atchNormalization)
#
#  activation_642 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_642[0][0
#  )                                                                  ]']
#
#  activation_643 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_643[0][0
#  )                                                                  ]']
#
#  activation_646 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_646[0][0
#  )                                                                  ]']
#
#  activation_647 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_647[0][0
#  )                                                                  ]']
#
#  batch_normalization_648 (B  (None, 5, 5, 192)            576       ['conv2d_648[0][0]']
#  atchNormalization)
#
#  activation_640 (Activation  (None, 5, 5, 320)            0         ['batch_normalization_640[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 5, 5, 768)            0         ['activation_642[0][0]',
#                                                                      'activation_643[0][0]']
#
#  concatenate_12 (Concatenat  (None, 5, 5, 768)            0         ['activation_646[0][0]',
#  e)                                                                  'activation_647[0][0]']
#
#  activation_648 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_648[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 5, 5, 2048)           0         ['activation_640[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_12[0][0]',
#                                                                      'activation_648[0][0]']
#
#  conv2d_653 (Conv2D)         (None, 5, 5, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_653 (B  (None, 5, 5, 448)            1344      ['conv2d_653[0][0]']
#  atchNormalization)
#
#  activation_653 (Activation  (None, 5, 5, 448)            0         ['batch_normalization_653[0][0
#  )                                                                  ]']
#
#  conv2d_650 (Conv2D)         (None, 5, 5, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_654 (Conv2D)         (None, 5, 5, 384)            1548288   ['activation_653[0][0]']
#
#  batch_normalization_650 (B  (None, 5, 5, 384)            1152      ['conv2d_650[0][0]']
#  atchNormalization)
#
#  batch_normalization_654 (B  (None, 5, 5, 384)            1152      ['conv2d_654[0][0]']
#  atchNormalization)
#
#  activation_650 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_650[0][0
#  )                                                                  ]']
#
#  activation_654 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_654[0][0
#  )                                                                  ]']
#
#  conv2d_651 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_650[0][0]']
#
#  conv2d_652 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_650[0][0]']
#
#  conv2d_655 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_654[0][0]']
#
#  conv2d_656 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_654[0][0]']
#
#  average_pooling2d_62 (Aver  (None, 5, 5, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_649 (Conv2D)         (None, 5, 5, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_651 (B  (None, 5, 5, 384)            1152      ['conv2d_651[0][0]']
#  atchNormalization)
#
#  batch_normalization_652 (B  (None, 5, 5, 384)            1152      ['conv2d_652[0][0]']
#  atchNormalization)
#
#  batch_normalization_655 (B  (None, 5, 5, 384)            1152      ['conv2d_655[0][0]']
#  atchNormalization)
#
#  batch_normalization_656 (B  (None, 5, 5, 384)            1152      ['conv2d_656[0][0]']
#  atchNormalization)
#
#  conv2d_657 (Conv2D)         (None, 5, 5, 192)            393216    ['average_pooling2d_62[0][0]']
#
#  batch_normalization_649 (B  (None, 5, 5, 320)            960       ['conv2d_649[0][0]']
#  atchNormalization)
#
#  activation_651 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_651[0][0
#  )                                                                  ]']
#
#  activation_652 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_652[0][0
#  )                                                                  ]']
#
#  activation_655 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_655[0][0
#  )                                                                  ]']
#
#  activation_656 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_656[0][0
#  )                                                                  ]']
#
#  batch_normalization_657 (B  (None, 5, 5, 192)            576       ['conv2d_657[0][0]']
#  atchNormalization)
#
#  activation_649 (Activation  (None, 5, 5, 320)            0         ['batch_normalization_649[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 5, 5, 768)            0         ['activation_651[0][0]',
#                                                                      'activation_652[0][0]']
#
#  concatenate_13 (Concatenat  (None, 5, 5, 768)            0         ['activation_655[0][0]',
#  e)                                                                  'activation_656[0][0]']
#
#  activation_657 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_657[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 5, 5, 2048)           0         ['activation_649[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_13[0][0]',
#                                                                      'activation_657[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['mixed10[0][0]']
#  ling2D)
#
# ==================================================================================================
# Total params: 21802784 (83.17 MB)
# Trainable params: 21768352 (83.04 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________
# None
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# CPU times: user 4min 27s, sys: 1min 37s, total: 6min 5s
# Wall time: 1min 33s
# (1050, 2048)

# %% [markdown]
# ### EfficientNetV2L
# D'après [Keras](https://keras.io/api/applications/#usage-examples-for-image-classification-models),
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/efficientnet_v2/EfficientNetV2L

# %%
# %%time
# Chargement du modèle pré-entraîné
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2L, preprocess_input

start_time = time.time()
input_tensor = Input(shape=(224, 224, 3))
base_model = EfficientNetV2L(weights='imagenet', input_tensor=input_tensor)
model = Model(inputs=base_model.inputs, outputs=base_model.layers[-2].output)
model._name = model_name = 'EfficientNetV2L'
print(model.summary())
print(f'Temps de la récupération du modèle en {round(time.time() - start_time,2)}s')

# Prédiction des features pour chaque image
start_time = time.time()
features = []
i=0 
for image_file in df["IMAGE"] :
    if i%100 == 0 : print(i)
    i +=1
    image = load_img(image_file, target_size=(224, 224))
    image = img_to_array(image) 
    image = np.expand_dims(image, axis=0)
    image = preprocess_input(image)
    features.append(model.predict(image, verbose=0)[0]) # predict from pretrained model

features = np.asarray(features)
print('Shape of features:', features.shape)
print(f'Temps de la prédiction des featuresen {round(time.time() - start_time,2)}s')

# Réduction ou pas du nombre de features en passant par un Kfold
start_time = time.time()
X_embedded, pred_label, pipeline = perform_dimensionality_reduction(features, use_pca=False, \
    perplexity=25, n_iter=2000, n_clusters=n_clusters, random_state=None)
print(f'Temps de réduction des dimensions des features en {round(time.time() - start_time,2)}s')

# Evaluations graphiques et sous forme de table du modèle non-supervisé
_,_,_ = evaluate_model(model_name, X_embedded, pred_label, true_label, le=le, my_cmap=my_cmap, \
    norm=norm, cat_list=cat_list, palette=palette)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l.h5
# 478307632/478307632 [==============================] - 15s 0us/step
# Model: "EfficientNetV2L"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_16 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  rescaling_3 (Rescaling)     (None, 224, 224, 3)          0         ['input_16[0][0]']
#
#  stem_conv (Conv2D)          (None, 112, 112, 32)         864       ['rescaling_3[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 112, 112, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 112, 112, 32)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 112, 112, 32)         9216      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 112, 112, 32)         128       ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 112, 112, 32)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1a_add (Add)           (None, 112, 112, 32)         0         ['block1a_project_activation[0
#                                                                     ][0]',
#                                                                      'stem_activation[0][0]']
#
#  block1b_project_conv (Conv  (None, 112, 112, 32)         9216      ['block1a_add[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 112, 112, 32)         128       ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 112, 112, 32)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 112, 112, 32)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 112, 112, 32)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_add[0][0]']
#
#  block1c_project_conv (Conv  (None, 112, 112, 32)         9216      ['block1b_add[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 112, 112, 32)         128       ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_project_activation  (None, 112, 112, 32)         0         ['block1c_project_bn[0][0]']
#   (Activation)
#
#  block1c_drop (Dropout)      (None, 112, 112, 32)         0         ['block1c_project_activation[0
#                                                                     ][0]']
#
#  block1c_add (Add)           (None, 112, 112, 32)         0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block1d_project_conv (Conv  (None, 112, 112, 32)         9216      ['block1c_add[0][0]']
#  2D)
#
#  block1d_project_bn (BatchN  (None, 112, 112, 32)         128       ['block1d_project_conv[0][0]']
#  ormalization)
#
#  block1d_project_activation  (None, 112, 112, 32)         0         ['block1d_project_bn[0][0]']
#   (Activation)
#
#  block1d_drop (Dropout)      (None, 112, 112, 32)         0         ['block1d_project_activation[0
#                                                                     ][0]']
#
#  block1d_add (Add)           (None, 112, 112, 32)         0         ['block1d_drop[0][0]',
#                                                                      'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 56, 56, 128)          36864     ['block1d_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 56, 56, 128)          512       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 56, 56, 128)          0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 56, 56, 64)           8192      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 56, 56, 256)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 56, 56, 64)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 56, 56, 64)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 56, 56, 256)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 56, 56, 64)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 56, 56, 64)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 56, 56, 256)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2d_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 56, 56, 64)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 56, 56, 64)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 56, 56, 256)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2e_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2e_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (Dropout)      (None, 56, 56, 64)           0         ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)           (None, 56, 56, 64)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2e_add[0][0]']
#  D)
#
#  block2f_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2f_expand_conv[0][0]']
#  rmalization)
#
#  block2f_expand_activation   (None, 56, 56, 256)          0         ['block2f_expand_bn[0][0]']
#  (Activation)
#
#  block2f_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2f_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2f_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2f_project_conv[0][0]']
#  ormalization)
#
#  block2f_drop (Dropout)      (None, 56, 56, 64)           0         ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)           (None, 56, 56, 64)           0         ['block2f_drop[0][0]',
#                                                                      'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2f_add[0][0]']
#  D)
#
#  block2g_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2g_expand_conv[0][0]']
#  rmalization)
#
#  block2g_expand_activation   (None, 56, 56, 256)          0         ['block2g_expand_bn[0][0]']
#  (Activation)
#
#  block2g_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2g_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2g_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2g_project_conv[0][0]']
#  ormalization)
#
#  block2g_drop (Dropout)      (None, 56, 56, 64)           0         ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)           (None, 56, 56, 64)           0         ['block2g_drop[0][0]',
#                                                                      'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 28, 28, 256)          147456    ['block2g_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 28, 28, 256)          1024      ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 28, 28, 256)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 28, 28, 96)           24576     ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 28, 28, 384)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 28, 28, 96)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 28, 28, 96)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 28, 28, 384)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 28, 28, 96)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 28, 28, 96)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 28, 28, 384)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3d_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (Dropout)      (None, 28, 28, 96)           0         ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)           (None, 28, 28, 96)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3d_add[0][0]']
#  D)
#
#  block3e_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3e_expand_conv[0][0]']
#  rmalization)
#
#  block3e_expand_activation   (None, 28, 28, 384)          0         ['block3e_expand_bn[0][0]']
#  (Activation)
#
#  block3e_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3e_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3e_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3e_project_conv[0][0]']
#  ormalization)
#
#  block3e_drop (Dropout)      (None, 28, 28, 96)           0         ['block3e_project_bn[0][0]']
#
#  block3e_add (Add)           (None, 28, 28, 96)           0         ['block3e_drop[0][0]',
#                                                                      'block3d_add[0][0]']
#
#  block3f_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3e_add[0][0]']
#  D)
#
#  block3f_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3f_expand_conv[0][0]']
#  rmalization)
#
#  block3f_expand_activation   (None, 28, 28, 384)          0         ['block3f_expand_bn[0][0]']
#  (Activation)
#
#  block3f_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3f_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3f_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3f_project_conv[0][0]']
#  ormalization)
#
#  block3f_drop (Dropout)      (None, 28, 28, 96)           0         ['block3f_project_bn[0][0]']
#
#  block3f_add (Add)           (None, 28, 28, 96)           0         ['block3f_drop[0][0]',
#                                                                      'block3e_add[0][0]']
#
#  block3g_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3f_add[0][0]']
#  D)
#
#  block3g_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3g_expand_conv[0][0]']
#  rmalization)
#
#  block3g_expand_activation   (None, 28, 28, 384)          0         ['block3g_expand_bn[0][0]']
#  (Activation)
#
#  block3g_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3g_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3g_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3g_project_conv[0][0]']
#  ormalization)
#
#  block3g_drop (Dropout)      (None, 28, 28, 96)           0         ['block3g_project_bn[0][0]']
#
#  block3g_add (Add)           (None, 28, 28, 96)           0         ['block3g_drop[0][0]',
#                                                                      'block3f_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 28, 28, 384)          36864     ['block3g_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 28, 28, 384)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 14, 14, 384)          3456      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 14, 14, 384)          1536      ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 14, 14, 384)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 384)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 24)             9240      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 384)            9600      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 14, 14, 384)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 14, 14, 192)          73728     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 14, 14, 192)          768       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 14, 14, 768)          147456    ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 14, 14, 768)          3072      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 14, 14, 768)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 14, 14, 768)          6912      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 14, 14, 768)          3072      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 14, 14, 768)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 768)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 768)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 48)             36912     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 768)            37632     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 14, 14, 768)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 14, 14, 192)          147456    ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 14, 14, 192)          768       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 14, 14, 192)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 14, 14, 192)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 14, 14, 768)          147456    ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 14, 14, 768)          3072      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 14, 14, 768)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 14, 14, 768)          6912      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 14, 14, 768)          3072      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 14, 14, 768)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 768)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 768)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 48)             36912     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 768)            37632     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 14, 14, 768)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 14, 14, 192)          147456    ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 14, 14, 192)          768       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 14, 14, 192)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 14, 14, 192)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 14, 14, 768)          147456    ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 14, 14, 768)          3072      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 14, 14, 768)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 14, 14, 768)          6912      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 14, 14, 768)          3072      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 14, 14, 768)          0         ['block4d_bn[0][0]']
#  tion)
#
# ...
#  block7d_project_conv (Conv  (None, 7, 7, 640)            2457600   ['block7d_se_excite[0][0]']
#  2D)
#
#  block7d_project_bn (BatchN  (None, 7, 7, 640)            2560      ['block7d_project_conv[0][0]']
#  ormalization)
#
#  block7d_drop (Dropout)      (None, 7, 7, 640)            0         ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)           (None, 7, 7, 640)            0         ['block7d_drop[0][0]',
#                                                                      'block7c_add[0][0]']
#
#  block7e_expand_conv (Conv2  (None, 7, 7, 3840)           2457600   ['block7d_add[0][0]']
#  D)
#
#  block7e_expand_bn (BatchNo  (None, 7, 7, 3840)           15360     ['block7e_expand_conv[0][0]']
#  rmalization)
#
#  block7e_expand_activation   (None, 7, 7, 3840)           0         ['block7e_expand_bn[0][0]']
#  (Activation)
#
#  block7e_dwconv2 (Depthwise  (None, 7, 7, 3840)           34560     ['block7e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7e_bn (BatchNormaliza  (None, 7, 7, 3840)           15360     ['block7e_dwconv2[0][0]']
#  tion)
#
#  block7e_activation (Activa  (None, 7, 7, 3840)           0         ['block7e_bn[0][0]']
#  tion)
#
#  block7e_se_squeeze (Global  (None, 3840)                 0         ['block7e_activation[0][0]']
#  AveragePooling2D)
#
#  block7e_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7e_se_squeeze[0][0]']
#  e)
#
#  block7e_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7e_se_reshape[0][0]']
#
#  block7e_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7e_se_reduce[0][0]']
#
#  block7e_se_excite (Multipl  (None, 7, 7, 3840)           0         ['block7e_activation[0][0]',
#  y)                                                                  'block7e_se_expand[0][0]']
#
#  block7e_project_conv (Conv  (None, 7, 7, 640)            2457600   ['block7e_se_excite[0][0]']
#  2D)
#
#  block7e_project_bn (BatchN  (None, 7, 7, 640)            2560      ['block7e_project_conv[0][0]']
#  ormalization)
#
#  block7e_drop (Dropout)      (None, 7, 7, 640)            0         ['block7e_project_bn[0][0]']
#
#  block7e_add (Add)           (None, 7, 7, 640)            0         ['block7e_drop[0][0]',
#                                                                      'block7d_add[0][0]']
#
#  block7f_expand_conv (Conv2  (None, 7, 7, 3840)           2457600   ['block7e_add[0][0]']
#  D)
#
#  block7f_expand_bn (BatchNo  (None, 7, 7, 3840)           15360     ['block7f_expand_conv[0][0]']
#  rmalization)
#
#  block7f_expand_activation   (None, 7, 7, 3840)           0         ['block7f_expand_bn[0][0]']
#  (Activation)
#
#  block7f_dwconv2 (Depthwise  (None, 7, 7, 3840)           34560     ['block7f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7f_bn (BatchNormaliza  (None, 7, 7, 3840)           15360     ['block7f_dwconv2[0][0]']
#  tion)
#
#  block7f_activation (Activa  (None, 7, 7, 3840)           0         ['block7f_bn[0][0]']
#  tion)
#
#  block7f_se_squeeze (Global  (None, 3840)                 0         ['block7f_activation[0][0]']
#  AveragePooling2D)
#
#  block7f_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7f_se_squeeze[0][0]']
#  e)
#
#  block7f_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7f_se_reshape[0][0]']
#
#  block7f_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7f_se_reduce[0][0]']
#
#  block7f_se_excite (Multipl  (None, 7, 7, 3840)           0         ['block7f_activation[0][0]',
#  y)                                                                  'block7f_se_expand[0][0]']
#
#  block7f_project_conv (Conv  (None, 7, 7, 640)            2457600   ['block7f_se_excite[0][0]']
#  2D)
#
#  block7f_project_bn (BatchN  (None, 7, 7, 640)            2560      ['block7f_project_conv[0][0]']
#  ormalization)
#
#  block7f_drop (Dropout)      (None, 7, 7, 640)            0         ['block7f_project_bn[0][0]']
#
#  block7f_add (Add)           (None, 7, 7, 640)            0         ['block7f_drop[0][0]',
#                                                                      'block7e_add[0][0]']
#
#  block7g_expand_conv (Conv2  (None, 7, 7, 3840)           2457600   ['block7f_add[0][0]']
#  D)
#
#  block7g_expand_bn (BatchNo  (None, 7, 7, 3840)           15360     ['block7g_expand_conv[0][0]']
#  rmalization)
#
#  block7g_expand_activation   (None, 7, 7, 3840)           0         ['block7g_expand_bn[0][0]']
#  (Activation)
#
#  block7g_dwconv2 (Depthwise  (None, 7, 7, 3840)           34560     ['block7g_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7g_bn (BatchNormaliza  (None, 7, 7, 3840)           15360     ['block7g_dwconv2[0][0]']
#  tion)
#
#  block7g_activation (Activa  (None, 7, 7, 3840)           0         ['block7g_bn[0][0]']
#  tion)
#
#  block7g_se_squeeze (Global  (None, 3840)                 0         ['block7g_activation[0][0]']
#  AveragePooling2D)
#
#  block7g_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7g_se_squeeze[0][0]']
#  e)
#
#  block7g_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7g_se_reshape[0][0]']
#
#  block7g_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7g_se_reduce[0][0]']
#
#  block7g_se_excite (Multipl  (None, 7, 7, 3840)           0         ['block7g_activation[0][0]',
#  y)                                                                  'block7g_se_expand[0][0]']
#
#  block7g_project_conv (Conv  (None, 7, 7, 640)            2457600   ['block7g_se_excite[0][0]']
#  2D)
#
#  block7g_project_bn (BatchN  (None, 7, 7, 640)            2560      ['block7g_project_conv[0][0]']
#  ormalization)
#
#  block7g_drop (Dropout)      (None, 7, 7, 640)            0         ['block7g_project_bn[0][0]']
#
#  block7g_add (Add)           (None, 7, 7, 640)            0         ['block7g_drop[0][0]',
#                                                                      'block7f_add[0][0]']
#
#  top_conv (Conv2D)           (None, 7, 7, 1280)           819200    ['block7g_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 7, 7, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 7, 7, 1280)           0         ['top_bn[0][0]']
#  )
#
#  avg_pool (GlobalAveragePoo  (None, 1280)                 0         ['top_activation[0][0]']
#  ling2D)
#
#  top_dropout (Dropout)       (None, 1280)                 0         ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 117746848 (449.17 MB)
# Trainable params: 117234272 (447.21 MB)
# Non-trainable params: 512576 (1.96 MB)
# __________________________________________________________________________________________________
# None
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# Shape of features: (1050, 1280)
#    v_measure  completeness  homogeneity     ARI
# 0     0.5329        0.5399       0.5261  0.4457
#               precision  recall  f1-score  support
# 0                  0.92    0.62      0.74    150.0
# 1                  0.79    0.76      0.77    150.0
# 2                  0.99    0.57      0.73    150.0
# 3                  0.58    0.58      0.58    150.0
# 4                  0.60    0.55      0.58    150.0
# 5                  0.63    0.79      0.70    150.0
# 6                  0.62    0.99      0.77    150.0
# accuracy           0.70    0.70      0.70      0.7
# macro avg          0.73    0.70      0.69   1050.0
# weighted avg       0.73    0.70      0.69   1050.0
# CPU times: user 25min 55s, sys: 19min 29s, total: 45min 24s
# Wall time: 7min 1s

# %% [markdown]
# ### EfficientNetB7

# %%
# %%time
# Chargement du modèle pré-entraîné
from tensorflow.keras.applications import EfficientNetB7

start_time = time.time()
input_tensor = Input(shape=(224, 224, 3))
base_model = EfficientNetV2L(weights='imagenet', input_tensor=input_tensor)
model = Model(inputs=base_model.inputs, outputs=base_model.layers[-2].output)
model._name = model_name = 'EfficientNetV2L'
print(model.summary())
print(f'Temps de la récupération du modèle en {round(time.time() - start_time,2)}s')

# Prédiction des features pour chaque image
start_time = time.time()
features = []
i=0 
for image_file in df["IMAGE"]:
    if i%100 == 0 : print(i)
    i +=1
    image = load_img(image_file, target_size=(224, 224))
    image = img_to_array(image) 
    image = np.expand_dims(image, axis=0)
    features.append(model.predict(image, verbose=0)[0]) # predict from pretrained model

features = np.asarray(features)
print('Shape of features:', features.shape)
print(f'Temps de la prédiction des features en {round(time.time() - start_time,2)}s')

# Réduction ou pas du nombre de features en passant par un Kfold
start_time = time.time()
X_embedded, pred_label, pipeline = perform_dimensionality_reduction(features, use_pca=False, \
    perplexity=25, n_iter=2000, n_clusters=n_clusters, random_state=None)
print(f'Temps de réduction des dimensions des features en {round(time.time() - start_time,2)}s')

# Evaluations graphiques et sous forme de table du modèle non-supervisé
_,_,_ = evaluate_model(model_name, X_embedded, pred_label, true_label, le=le, my_cmap=my_cmap, \
    norm=norm, cat_list=cat_list, palette=palette)
# Out:
# Model: "EfficientNetV2L"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_20 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  rescaling_7 (Rescaling)     (None, 224, 224, 3)          0         ['input_20[0][0]']
#
#  stem_conv (Conv2D)          (None, 112, 112, 32)         864       ['rescaling_7[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 112, 112, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 112, 112, 32)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 112, 112, 32)         9216      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 112, 112, 32)         128       ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 112, 112, 32)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1a_add (Add)           (None, 112, 112, 32)         0         ['block1a_project_activation[0
#                                                                     ][0]',
#                                                                      'stem_activation[0][0]']
#
#  block1b_project_conv (Conv  (None, 112, 112, 32)         9216      ['block1a_add[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 112, 112, 32)         128       ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 112, 112, 32)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 112, 112, 32)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 112, 112, 32)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_add[0][0]']
#
#  block1c_project_conv (Conv  (None, 112, 112, 32)         9216      ['block1b_add[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 112, 112, 32)         128       ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_project_activation  (None, 112, 112, 32)         0         ['block1c_project_bn[0][0]']
#   (Activation)
#
#  block1c_drop (Dropout)      (None, 112, 112, 32)         0         ['block1c_project_activation[0
#                                                                     ][0]']
#
#  block1c_add (Add)           (None, 112, 112, 32)         0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block1d_project_conv (Conv  (None, 112, 112, 32)         9216      ['block1c_add[0][0]']
#  2D)
#
#  block1d_project_bn (BatchN  (None, 112, 112, 32)         128       ['block1d_project_conv[0][0]']
#  ormalization)
#
#  block1d_project_activation  (None, 112, 112, 32)         0         ['block1d_project_bn[0][0]']
#   (Activation)
#
#  block1d_drop (Dropout)      (None, 112, 112, 32)         0         ['block1d_project_activation[0
#                                                                     ][0]']
#
#  block1d_add (Add)           (None, 112, 112, 32)         0         ['block1d_drop[0][0]',
#                                                                      'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 56, 56, 128)          36864     ['block1d_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 56, 56, 128)          512       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 56, 56, 128)          0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 56, 56, 64)           8192      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 56, 56, 256)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 56, 56, 64)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 56, 56, 64)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 56, 56, 256)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 56, 56, 64)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 56, 56, 64)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 56, 56, 256)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2d_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 56, 56, 64)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 56, 56, 64)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 56, 56, 256)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2e_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2e_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (Dropout)      (None, 56, 56, 64)           0         ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)           (None, 56, 56, 64)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2e_add[0][0]']
#  D)
#
#  block2f_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2f_expand_conv[0][0]']
#  rmalization)
#
#  block2f_expand_activation   (None, 56, 56, 256)          0         ['block2f_expand_bn[0][0]']
#  (Activation)
#
#  block2f_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2f_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2f_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2f_project_conv[0][0]']
#  ormalization)
#
#  block2f_drop (Dropout)      (None, 56, 56, 64)           0         ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)           (None, 56, 56, 64)           0         ['block2f_drop[0][0]',
#                                                                      'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2  (None, 56, 56, 256)          147456    ['block2f_add[0][0]']
#  D)
#
#  block2g_expand_bn (BatchNo  (None, 56, 56, 256)          1024      ['block2g_expand_conv[0][0]']
#  rmalization)
#
#  block2g_expand_activation   (None, 56, 56, 256)          0         ['block2g_expand_bn[0][0]']
#  (Activation)
#
#  block2g_project_conv (Conv  (None, 56, 56, 64)           16384     ['block2g_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2g_project_bn (BatchN  (None, 56, 56, 64)           256       ['block2g_project_conv[0][0]']
#  ormalization)
#
#  block2g_drop (Dropout)      (None, 56, 56, 64)           0         ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)           (None, 56, 56, 64)           0         ['block2g_drop[0][0]',
#                                                                      'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 28, 28, 256)          147456    ['block2g_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 28, 28, 256)          1024      ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 28, 28, 256)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 28, 28, 96)           24576     ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 28, 28, 384)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 28, 28, 96)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 28, 28, 96)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 28, 28, 384)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 28, 28, 96)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 28, 28, 96)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 28, 28, 384)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3d_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (Dropout)      (None, 28, 28, 96)           0         ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)           (None, 28, 28, 96)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3d_add[0][0]']
#  D)
#
#  block3e_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3e_expand_conv[0][0]']
#  rmalization)
#
#  block3e_expand_activation   (None, 28, 28, 384)          0         ['block3e_expand_bn[0][0]']
#  (Activation)
#
#  block3e_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3e_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3e_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3e_project_conv[0][0]']
#  ormalization)
#
#  block3e_drop (Dropout)      (None, 28, 28, 96)           0         ['block3e_project_bn[0][0]']
#
#  block3e_add (Add)           (None, 28, 28, 96)           0         ['block3e_drop[0][0]',
#                                                                      'block3d_add[0][0]']
#
#  block3f_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3e_add[0][0]']
#  D)
#
#  block3f_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3f_expand_conv[0][0]']
#  rmalization)
#
#  block3f_expand_activation   (None, 28, 28, 384)          0         ['block3f_expand_bn[0][0]']
#  (Activation)
#
#  block3f_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3f_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3f_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3f_project_conv[0][0]']
#  ormalization)
#
#  block3f_drop (Dropout)      (None, 28, 28, 96)           0         ['block3f_project_bn[0][0]']
#
#  block3f_add (Add)           (None, 28, 28, 96)           0         ['block3f_drop[0][0]',
#                                                                      'block3e_add[0][0]']
#
#  block3g_expand_conv (Conv2  (None, 28, 28, 384)          331776    ['block3f_add[0][0]']
#  D)
#
#  block3g_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block3g_expand_conv[0][0]']
#  rmalization)
#
#  block3g_expand_activation   (None, 28, 28, 384)          0         ['block3g_expand_bn[0][0]']
#  (Activation)
#
#  block3g_project_conv (Conv  (None, 28, 28, 96)           36864     ['block3g_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3g_project_bn (BatchN  (None, 28, 28, 96)           384       ['block3g_project_conv[0][0]']
#  ormalization)
#
#  block3g_drop (Dropout)      (None, 28, 28, 96)           0         ['block3g_project_bn[0][0]']
#
#  block3g_add (Add)           (None, 28, 28, 96)           0         ['block3g_drop[0][0]',
#                                                                      'block3f_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 28, 28, 384)          36864     ['block3g_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 28, 28, 384)          1536      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 28, 28, 384)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 14, 14, 384)          3456      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 14, 14, 384)          1536      ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 14, 14, 384)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 384)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 24)             9240      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 384)            9600      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 14, 14, 384)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 14, 14, 192)          73728     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 14, 14, 192)          768       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 14, 14, 768)          147456    ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 14, 14, 768)          3072      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 14, 14, 768)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 14, 14, 768)          6912      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 14, 14, 768)          3072      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 14, 14, 768)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 768)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 768)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 48)             36912     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 768)            37632     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 14, 14, 768)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 14, 14, 192)          147456    ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 14, 14, 192)          768       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 14, 14, 192)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 14, 14, 192)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 14, 14, 768)          147456    ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 14, 14, 768)          3072      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 14, 14, 768)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 14, 14, 768)          6912      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 14, 14, 768)          3072      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 14, 14, 768)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 768)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 768)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 48)             36912     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 768)            37632     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 14, 14, 768)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 14, 14, 192)          147456    ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 14, 14, 192)          768       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 14, 14, 192)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 14, 14, 192)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 14, 14, 768)          147456    ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 14, 14, 768)          3072      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 14, 14, 768)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 14, 14, 768)          6912      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 14, 14, 768)          3072      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 14, 14, 768)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 768)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
# ...
#
#  block7d_project_bn (BatchN  (None, 7, 7, 640)            2560      ['block7d_project_conv[0][0]']
#  ormalization)
#
#  block7d_drop (Dropout)      (None, 7, 7, 640)            0         ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)           (None, 7, 7, 640)            0         ['block7d_drop[0][0]',
#                                                                      'block7c_add[0][0]']
#
#  block7e_expand_conv (Conv2  (None, 7, 7, 3840)           2457600   ['block7d_add[0][0]']
#  D)
#
#  block7e_expand_bn (BatchNo  (None, 7, 7, 3840)           15360     ['block7e_expand_conv[0][0]']
#  rmalization)
#
#  block7e_expand_activation   (None, 7, 7, 3840)           0         ['block7e_expand_bn[0][0]']
#  (Activation)
#
#  block7e_dwconv2 (Depthwise  (None, 7, 7, 3840)           34560     ['block7e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7e_bn (BatchNormaliza  (None, 7, 7, 3840)           15360     ['block7e_dwconv2[0][0]']
#  tion)
#
#  block7e_activation (Activa  (None, 7, 7, 3840)           0         ['block7e_bn[0][0]']
#  tion)
#
#  block7e_se_squeeze (Global  (None, 3840)                 0         ['block7e_activation[0][0]']
#  AveragePooling2D)
#
#  block7e_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7e_se_squeeze[0][0]']
#  e)
#
#  block7e_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7e_se_reshape[0][0]']
#
#  block7e_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7e_se_reduce[0][0]']
#
#  block7e_se_excite (Multipl  (None, 7, 7, 3840)           0         ['block7e_activation[0][0]',
#  y)                                                                  'block7e_se_expand[0][0]']
#
#  block7e_project_conv (Conv  (None, 7, 7, 640)            2457600   ['block7e_se_excite[0][0]']
#  2D)
#
#  block7e_project_bn (BatchN  (None, 7, 7, 640)            2560      ['block7e_project_conv[0][0]']
#  ormalization)
#
#  block7e_drop (Dropout)      (None, 7, 7, 640)            0         ['block7e_project_bn[0][0]']
#
#  block7e_add (Add)           (None, 7, 7, 640)            0         ['block7e_drop[0][0]',
#                                                                      'block7d_add[0][0]']
#
#  block7f_expand_conv (Conv2  (None, 7, 7, 3840)           2457600   ['block7e_add[0][0]']
#  D)
#
#  block7f_expand_bn (BatchNo  (None, 7, 7, 3840)           15360     ['block7f_expand_conv[0][0]']
#  rmalization)
#
#  block7f_expand_activation   (None, 7, 7, 3840)           0         ['block7f_expand_bn[0][0]']
#  (Activation)
#
#  block7f_dwconv2 (Depthwise  (None, 7, 7, 3840)           34560     ['block7f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7f_bn (BatchNormaliza  (None, 7, 7, 3840)           15360     ['block7f_dwconv2[0][0]']
#  tion)
#
#  block7f_activation (Activa  (None, 7, 7, 3840)           0         ['block7f_bn[0][0]']
#  tion)
#
#  block7f_se_squeeze (Global  (None, 3840)                 0         ['block7f_activation[0][0]']
#  AveragePooling2D)
#
#  block7f_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7f_se_squeeze[0][0]']
#  e)
#
#  block7f_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7f_se_reshape[0][0]']
#
#  block7f_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7f_se_reduce[0][0]']
#
#  block7f_se_excite (Multipl  (None, 7, 7, 3840)           0         ['block7f_activation[0][0]',
#  y)                                                                  'block7f_se_expand[0][0]']
#
#  block7f_project_conv (Conv  (None, 7, 7, 640)            2457600   ['block7f_se_excite[0][0]']
#  2D)
#
#  block7f_project_bn (BatchN  (None, 7, 7, 640)            2560      ['block7f_project_conv[0][0]']
#  ormalization)
#
#  block7f_drop (Dropout)      (None, 7, 7, 640)            0         ['block7f_project_bn[0][0]']
#
#  block7f_add (Add)           (None, 7, 7, 640)            0         ['block7f_drop[0][0]',
#                                                                      'block7e_add[0][0]']
#
#  block7g_expand_conv (Conv2  (None, 7, 7, 3840)           2457600   ['block7f_add[0][0]']
#  D)
#
#  block7g_expand_bn (BatchNo  (None, 7, 7, 3840)           15360     ['block7g_expand_conv[0][0]']
#  rmalization)
#
#  block7g_expand_activation   (None, 7, 7, 3840)           0         ['block7g_expand_bn[0][0]']
#  (Activation)
#
#  block7g_dwconv2 (Depthwise  (None, 7, 7, 3840)           34560     ['block7g_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7g_bn (BatchNormaliza  (None, 7, 7, 3840)           15360     ['block7g_dwconv2[0][0]']
#  tion)
#
#  block7g_activation (Activa  (None, 7, 7, 3840)           0         ['block7g_bn[0][0]']
#  tion)
#
#  block7g_se_squeeze (Global  (None, 3840)                 0         ['block7g_activation[0][0]']
#  AveragePooling2D)
#
#  block7g_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7g_se_squeeze[0][0]']
#  e)
#
#  block7g_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7g_se_reshape[0][0]']
#
#  block7g_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7g_se_reduce[0][0]']
#
#  block7g_se_excite (Multipl  (None, 7, 7, 3840)           0         ['block7g_activation[0][0]',
#  y)                                                                  'block7g_se_expand[0][0]']
#
#  block7g_project_conv (Conv  (None, 7, 7, 640)            2457600   ['block7g_se_excite[0][0]']
#  2D)
#
#  block7g_project_bn (BatchN  (None, 7, 7, 640)            2560      ['block7g_project_conv[0][0]']
#  ormalization)
#
#  block7g_drop (Dropout)      (None, 7, 7, 640)            0         ['block7g_project_bn[0][0]']
#
#  block7g_add (Add)           (None, 7, 7, 640)            0         ['block7g_drop[0][0]',
#                                                                      'block7f_add[0][0]']
#
#  top_conv (Conv2D)           (None, 7, 7, 1280)           819200    ['block7g_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 7, 7, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 7, 7, 1280)           0         ['top_bn[0][0]']
#  )
#
#  avg_pool (GlobalAveragePoo  (None, 1280)                 0         ['top_activation[0][0]']
#  ling2D)
#
#  top_dropout (Dropout)       (None, 1280)                 0         ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 117746848 (449.17 MB)
# Trainable params: 117234272 (447.21 MB)
# Non-trainable params: 512576 (1.96 MB)
# __________________________________________________________________________________________________
# None
# Temps de la récupération du modèle en 1.2e+01s
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# Shape of features: (1050, 1280)
# Temps de la prédiction des features en 4.1e+02s
# Temps de réduction des dimensions des features en 3.1e+01s
#    v_measure  completeness  homogeneity     ARI
# 0     0.4622        0.5038       0.4269  0.3382
#               precision  recall  f1-score  support
# 0                  0.69    0.42      0.52   150.00
# 1                  0.78    0.75      0.76   150.00
# 2                  1.00    0.35      0.51   150.00
# 3                  0.00    0.00      0.00   150.00
# 4                  0.39    0.85      0.53   150.00
# 5                  0.53    0.80      0.64   150.00
# 6                  0.71    0.99      0.83   150.00
# accuracy           0.59    0.59      0.59     0.59
# macro avg          0.59    0.59      0.54  1050.00
# weighted avg       0.59    0.59      0.54  1050.00
# CPU times: user 27min 7s, sys: 20min 33s, total: 47min 40s
# Wall time: 7min 31s
